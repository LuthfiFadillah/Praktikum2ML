# %%
import pandas as pd

# Load Dataset
dataset_training = pd.read_csv('data_training_praktikum.csv')
dataset.describe(include='all')

dataset_testing = pd.read_csv('data_testing_praktikum_tanpakelas.csv')

# %%
# Describe all columns
for i in range (60):
    print(dataset[dataset.columns[i]].describe())
    print()
# Out:
# count    12594.000000
# mean         0.237891
# std          0.425809
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: cont1, dtype: float64
#
# count    12594.000000
# mean         0.526044
# std          0.499341
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: cont2a, dtype: float64
#
# count    12594.000000
# mean         0.328331
# std          0.469625
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: cont3, dtype: float64
#
# count     12594
# unique       10
# top           F
# freq       5029
# Name: loc, dtype: object
#
# count        12594
# unique           7
# top       last_stc
# freq          2077
# Name: struct1, dtype: object
#
# count     12594
# unique        3
# top       Final
# freq       5232
# Name: struct2, dtype: object
#
# ...

# %%
# Select all Categorical columns and print frequency
nominal = dataset.select_dtypes(include=['object'])
for i in range (7):
    print(nominal[nominal.columns[i]].value_counts())
    print()
# Out:
# F    5029
# G    1268
# E    1259
# H    1252
# J     677
# B     634
# D     634
# I     630
# C     627
# A     584
# Name: loc, dtype: int64
#
# last_stc                    2077
# second_or_third_last_stc    1808
# second_or_third_stc         1808
# second_third                1800
# first_third                 1796
# last_third                  1796
# first_stc                   1509
# Name: struct1, dtype: int64
#
# Final      5232
# Medial     4218
# Initial    3144
# Name: struct2, dtype: int64
#
# NonPrototypical    3067
# Introduction       1995
# Method             1740
# Experiment         1170
# Result              760
# Related Work        649
# Conclusion          604
# Abstract            578
# Discussion          418
# Data                409
# Evaluation          360
# Solution            313
# Implementation      247
# Problem             134
# Example             104
# Further Work         38
# Limitation            8
# Name: struct3, dtype: int64
#
# ...

# %%
# Drop Columns with mean = 0
list_column = []
import numpy as np
for i in range (60):
    if (dataset[dataset.columns[i]].dtype != np.object and dataset[dataset.columns[i]].mean() == 0):
        list_column.append(dataset.columns[i])
        
dropped_dataset = dataset
for column in list_column:
    dropped_dataset = dropped_dataset.drop(column,axis=1)
    
print(dropped_dataset.describe(include ='all'))
# Out:
#                cont1        cont2a         cont3    loc   struct1 struct2  \
# count   12594.000000  12594.000000  12594.000000  12594     12594   12594
# unique           NaN           NaN           NaN     10         7       3
# top              NaN           NaN           NaN      F  last_stc   Final
# freq             NaN           NaN           NaN   5029      2077    5232
# mean        0.237891      0.526044      0.328331    NaN       NaN     NaN
# std         0.425809      0.499341      0.469625    NaN       NaN     NaN
# min         0.000000      0.000000      0.000000    NaN       NaN     NaN
# 25%         0.000000      0.000000      0.000000    NaN       NaN     NaN
# 50%         0.000000      1.000000      0.000000    NaN       NaN     NaN
# 75%         0.000000      1.000000      1.000000    NaN       NaN     NaN
# max         1.000000      1.000000      1.000000    NaN       NaN     NaN
#
#                 struct3        length   cit1   cit2     ...      \
# ...

# %%
# Encode Categorical Column using One-Hot Encoder
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
encoded_dataset = enc.fit_transform(dataset)

print(type(encoded_dataset))
# Out:
# <class 'scipy.sparse.csr.csr_matrix'>
